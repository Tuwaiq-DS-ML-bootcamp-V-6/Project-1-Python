# %%
class Student:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade

    def edit_name(self, new_name):
        self.name = new_name

    def edit_age(self, new_age):
        self.age = new_age

    def edit_grade(self, new_grade):
        self.grade = new_grade

    def display_info(self):
        print(f"Name: {self.name}, Age: {self.age}, Grade: {self.grade}")

# %%
# Mohammed Alaklabi TASKS 

def add_element(data_structure, key, value):
    if key not in data_structure:
        data_structure[key] = value
    else:
        print(f"The key '{key}' already exists in the dictionary.")

def remove_element(data_structure, key):
    if key in data_structure:
        del data_structure[key]
    else:
        print(f"The key '{key}' does not exist in the dictionary.")


print("Original Dictionary:", my_dict)

# for Adding an element
add_element(my_dict, 'd', 4)
print("Dictionary after adding an element:", my_dict)

# for Removing an element
remove_element(my_dict, 'b')
print("Dictionary after removing an element:", my_dict)

# Mohammed Alaklabi TASKS ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

def view(students, indent = 0):
    for key, value in students.items():
        if isinstance(value, dict):
            print(str(key) + ":" + " " * indent)
            view(value, indent + 1)
        else:
            print(str(key) + ": " + str(value))
    print()

# %%
def main():
    print('''Student Management System
    1- View Students
    2- Search Student
    3- Filter Students
    4- Add Student
    5- Remove Student
    6- Edit Student
    7- Exit
    ''')
    while(True):
        user_input = input("Choose Your Option\n>> ")
        if user_input == "1":
            pass
        elif user_input == "2":
            user_input = input('Enter Student Name or ID')
            pass
        elif user_input == "3":
            user_input = input('''Filter By:
            1- Juniors
            2- Seniors
            3- GPA
            4- Pass
            5- Fail
            ''')
            pass
        elif user_input == "4":
            data = input("Enter Student Name, GPA, Hours, final grade out of 40, HW out of 20, quiz grade out of 20: ").split()
            pass
        elif user_input == "5":
            user_input = input('Enter Student Name or ID: ')
            pass
        elif user_input == "6":
            user_input = input('Enter the field to edit: ')
            pass
        elif user_input == "7":
            break
